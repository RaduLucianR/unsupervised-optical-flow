# %% [markdown]
# # Neural Networks and Deep Learning with PyTorch

# %% [markdown]
# Full Course Syllabus: http://deeplizard.com/learn/video/v5cngxo4mIg

# %% [markdown]
# # Part 2: CNN Fashion MNIST Image Classification Project

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import torchvision
import torchvision.transforms as transforms

import numpy as np
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix
from resources.plotcm import plot_confusion_matrix

# %% [markdown]
# # Section 1: Data and Data Processing

# %% [markdown]
# Importance of Data in Deep Learning - http://deeplizard.com/learn/video/EqpzfvxBx30
# Extract, Transform, Load (ETL) - http://deeplizard.com/learn/video/8n-TGaBZnk4
# PyTorch Datasets and DataLoaders - http://deeplizard.com/learn/video/mUueSPmcOBc

# %%
train_set = torchvision.datasets.FashionMNIST(
    root='./data'
    ,train=True
    ,download=True
    ,transform=transforms.Compose([
        transforms.ToTensor()
    ])
)

train_loader = torch.utils.data.DataLoader(train_set, batch_size=1000, shuffle=True)

# %% [markdown]
# # Section 2: Neural Networks and PyTorch Design

# %% [markdown]
# Build PyTorch CNN - http://deeplizard.com/learn/video/k4jY9L8H89U
# CNN Layers - http://deeplizard.com/learn/video/IKOHHItzukk
# CNN Weights - http://deeplizard.com/learn/video/stWU37L91Yc
# Callable Neural Networks - http://deeplizard.com/learn/video/rcc86nXKwkw
# CNN Forward Method - http://deeplizard.com/learn/video/MasG7tZj-hw

# %%
class Network(nn.Module):
    def __init__(self):
        super(Network, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=6, kernel_size=5)
        self.conv2 = nn.Conv2d(in_channels=6, out_channels=12, kernel_size=5)
        
        self.fc1 = nn.Linear(in_features=12 * 4 * 4, out_features=120)
        self.fc2 = nn.Linear(in_features=120, out_features=60)
        self.out = nn.Linear(in_features=60, out_features=10)
        
    def forward(self, t):
        # (1) input layer
        t = t
        
        # (2) hidden conv layer
        t = self.conv1(t)
        t = F.relu(t)
        t = F.max_pool2d(t, kernel_size=2, stride=2)
        
        # (3) hidden conv layer
        t = self.conv2(t)
        t = F.relu(t)
        t = F.max_pool2d(t, kernel_size=2, stride=2)
        
        # (4) hidden linear layer
        t = t.reshape(-1, 12 * 4 * 4)
        t = self.fc1(t)
        t = F.relu(t)
        
        # (5) hidden linear layer
        t = self.fc2(t)
        t = F.relu(t)
        
        # (6) output layer
        t = self.out(t)
        #t = F.softmax(t, dim=1)
        
        return t

# %%
network = Network()

# %% [markdown]
# # Section 3: Training Neural Networks

# %%
optimizer = optim.Adam(network.parameters(), lr=0.001) # Optimizer

# %%
# The training loop
for epoch in range(1):
    total_correct = 0
    total_loss = 0
    for batch in train_loader:
        images, labels = batch
        
        optimizer.zero_grad()
        preds = network(images)
        
        loss = F.cross_entropy(preds, labels)
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
        total_correct += preds.argmax(dim=1).eq(labels).sum().item()

    print('epoch:', epoch, "total_correct:", total_correct, "loss:", total_loss)
# Out:
# epoch: 0 total_correct: 28681 loss: 90.19187927246094

# %%
# Function to get all predictions at once
@torch.no_grad()
def get_all_preds(model, loader):
    all_preds = torch.tensor([])
    for batch in loader:
        images, labels = batch

        preds = model(images)
        all_preds = torch.cat(
            (all_preds, preds)
            ,dim=0
        )
    return all_preds

# %%
# Analytics
prediction_loader = torch.utils.data.DataLoader(train_set, batch_size=10000)
train_preds = get_all_preds(network, prediction_loader)
preds_correct = train_preds.argmax(dim=1).eq(train_set.targets).sum().item()

print('total correct:', preds_correct)
print('accuracy:', preds_correct / len(train_set))
# Out:
# total correct: 38822
# accuracy: 0.6470333333333333

# %%
# Graphical analytics
cm = confusion_matrix(train_set.targets, train_preds.argmax(dim=1))
names = ('T-shirt/top','Trouser','Pullover','Dress','Coat','Sandal','Shirt','Sneaker','Bag','Ankle boot')
plt.figure(figsize=(10,10))
plot_confusion_matrix(cm, names)
# Out:
# Confusion matrix, without normalization
# [[4450  131   23  518  276   11  477    2   84   28]
#  [ 221 5189   37  429   75    0   41    0    5    3]
#  [ 190   29  422   35 3740   12  991    3  570    8]
#  [1136  779    3 3649  215    2  199    0   13    4]
#  [ 567   32  169  266 4337    4  450    0  173    2]
#  [   0    3    0   20    0 3572   16 1704   84  601]
#  [1375   25  262  212 2378   15 1273    0  455    5]
#  [   0    0    0    0    0  235    0 5013   45  707]
#  [  28    9   45   61  306   29  160   52 5292   18]
#  [   1    0    0    9    0   50   18  280   17 5625]]
